# %%
# This file was developed using tf version 1.13.1
# Other versions might run into problems.
# It may be required to restart the runtime after downgrading
# !pip install tensorflow-gpu==1.13.1
# tf_metrics was used but its maintenance is not guaranteed
# !pip install git+https://github.com/guillaumegenthial/tf_metrics.git
  
import datetime
import json
import os
import pprint
import random
import string
import sys
import tensorflow as tf
from google.colab import drive

# Get NLP-Praktikum specific BERT repo
# !test -d bert_repo || git clone https://github.com/joroGER/bert.git bert_repo
if not 'bert_repo' in sys.path:
  sys.path += ['bert_repo']
import run_classifier

# %%
# Mount drive
drive.mount('/content/drive')
# This path might vary depending on your drive
drive_path = "drive/My Drive"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Should print '/device:GPU:0'
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# This should be replaced by the newest version of BERT
bert_version = "multi_cased_L-12_H-768_A-12"
bert_folder = os.path.join(drive_path, bert_version)
bert_config_file = os.path.join(bert_folder, "bert_config.json")
vocab_file = os.path.join(bert_folder, "vocab.txt")
init_checkpoint = os.path.join(bert_folder, "bert_model.ckpt")
data_dir = os.path.join(drive_path, "csv_dataset/fine_foods")
output_dir = os.path.join(drive_path, "model")
if not os.path.isdir(output_dir):
  os.mkdir(output_dir)
# implemented tasks: fine_foods, amazon, organic
task_name = "fine_foods"
do_lower_case = False
# batch size and max_seq_length are essential for VRAM usage
# 14GB VRAM can deal with 128 max_seq_length length and 32 batch_size
# 10GB VRAM can deal with 64 max_seq_length length and 32 batch_size
max_seq_length = 64
batch_size = 32
save_checkpoints_steps = 1000
# sometimes a lower or higher learning rate performs better
learning_rate = 1e-5
warmup_proportion = 0.02
num_train_epochs = 10
# should change depending on your task
dataset_size = 100000
do_train = True
do_eval = True

run_classifier.run(bert_config_file,
                    max_seq_length,
                    output_dir,
                    task_name,
                    do_lower_case,
                    vocab_file,
                    save_checkpoints_steps,
                    data_dir,
                    learning_rate,
                    warmup_proportion,
                    batch_size,
                    dataset_size,
                    num_train_epochs,
                    init_checkpoint,
                    do_train,
                    do_eval)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'drive/My Drive/model', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 5, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 10, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f63a6743e10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:***** Running training *****
# ...
